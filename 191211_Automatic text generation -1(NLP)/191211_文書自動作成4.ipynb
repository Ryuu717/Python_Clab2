# %% [markdown]
# # 1. 対話コーパスの前処理

# %% [markdown]
#     -データの読み込み
#     -ルビ削除

# %%
import re

novels = ["gingatetsudono_yoru.txt", "serohikino_goshu.txt", "chumonno_oi_ryoriten.txt",
         "gusukobudorino_denki.txt", "kaeruno_gomugutsu.txt", "kaino_hi.txt", "kashiwabayashino_yoru.txt",
         "kazeno_matasaburo.txt", "kiirono_tomato.txt", "oinomorito_zarumori.txt"]  # 青空文庫より

text = ""
for novel in novels:
    with open("kenji_novels/"+novel, mode="r", encoding="utf-8") as f:  # ファイルの読み込み
        text_novel = f.read()
    text_novel = re.sub("《[^》]+》", "", text_novel)  # ルビの削除
    text_novel = re.sub("［[^］]+］", "", text_novel)  # 読みの注意の削除
    text_novel = re.sub("〔[^〕]+〕", "", text_novel)  # 読みの注意の削除
    text_novel = re.sub("[ 　\n「」『』（）｜※＊…]", "", text_novel)  # 全角半角スペース、改行、その他記号の削除
    text += text_novel

print("文字数:", len(text))
print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-051708138095> in <module>()
#       7 text = ""
#       8 for novel in novels:
# ----> 9     with open("kenji_novels/"+novel, mode="r", encoding="utf-8") as f:  # ファイルの読み込み
#      10         text_novel = f.read()
#      11     text_novel = re.sub("《[^》]+》", "", text_novel)  # ルビの削除
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kenji_novels/gingatetsudono_yoru.txt'

# %% [markdown]
# # 2. ひらがな変換

# %%
from pykakasi import kakasi

seperator = "。"  # 。をセパレータに指定
sentence_list = text.split(seperator)  # セパレーターを使って文章をリストに分割する
sentence_list.pop() # 最後の要素は空の文字列になるので、削除
sentence_list = [x+seperator for x in sentence_list]  # 文章の最後に。を追加

kakasi = kakasi()
kakasi.setMode("J", "H")  # J(漢字) からH(ひらがな)へ
conv = kakasi.getConverter()
for sentence in sentence_list:
    print(sentence)
    print(conv.do(sentence))
    print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-43e5b90370de> in <module>()
# ----> 1 from pykakasi import kakasi
#       2
#       3 seperator = "。"  # 。をセパレータに指定
#       4 sentence_list = text.split(seperator)  # セパレーターを使って文章をリストに分割する
#       5 sentence_list.pop() # 最後の要素は空の文字列になるので、削除
#
# ModuleNotFoundError: No module named 'pykakasi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
text = text.replace("苹果", "ひょうか")

seperator = "。"
sentence_list = text.split(seperator) 
sentence_list.pop() 
sentence_list = [x+seperator for x in sentence_list]

for sentence in sentence_list:
    print(sentence)
    print(conv.do(sentence))
    print()

# %% [markdown]
# # 3. 文字一覧確認

# %%
kana_text = conv.do(text)  # 全体をひらがなに変換
print(set(kana_text))  # set()で文字の重複をなくす
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c2dc253129b4> in <module>()
# ----> 1 kana_text = conv.do(text)  # 全体をひらがなに変換
#       2 print(set(kana_text))  # set()で文字の重複をなくす
#
# NameError: name 'conv' is not defined

# %% [markdown]
# # 4. テキストデータの保存

# %%
print(kana_text)
with open("kana_kenji.txt", mode="w", encoding="utf-8") as f:
    f.write(kana_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-784997d428a8> in <module>()
# ----> 1 print(kana_text)
#       2 with open("kana_kenji.txt", mode="w", encoding="utf-8") as f:
#       3     f.write(kana_text)
#
# NameError: name 'kana_text' is not defined

# %% [markdown]
# # 5. 対話の学習

# %%
import pickle

hiragana = "ぁあぃいぅうぇえぉおかがきぎくぐけげこごさざしじすずせぜそぞ\
ただちぢっつづてでとどなにぬねのはばぱひびぴふぶぷへべぺほぼぽ\
まみむめもゃやゅゆょよらりるれろゎわゐゑをん"

katakana = "ァアィイゥウェエォオカガキギクグケゲコゴサザシジスズセゼソゾ\
タダチヂッツヅテデトドナニヌネノハバパヒビピフブプヘベペホボポ\
マミムメモャヤュユョヨラリルレロヮワヰヱヲンヴ"

chars = hiragana + katakana

with open("kana_kenji.txt", mode="r", encoding="utf-8") as f:  # 前処理したファイル
    text = f.read()
    
for char in text:  # ひらがな、カタカナ以外でコーパスに使われている文字を追加
    if char not in chars:
        chars += char
        
chars += "\t\n"  # タブと改行を追加
        
chars_list = sorted(list(chars))  # 文字列をリストに変換してソートする
print(chars_list)

with open("kana_chars.pickle", mode="wb") as f:  # pickleで保存
    pickle.dump(chars_list, f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d0a0551e97e2> in <module>()
#       7 chars = hiragana + katakana
#       8
# ----> 9 with open("kana_kenji.txt", mode="r", encoding="utf-8") as f:  # 前処理したファイル
#      10     text = f.read()
#      11
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kana_kenji.txt'

# %% [markdown]
# # 7. 文字のベクトル化

# %%
import numpy as np

# インデックスと文字で辞書を作成
char_indices = {}
for i, char in enumerate(chars_list):
    char_indices[char] = i
indices_char = {}
for i, char in enumerate(chars_list):
    indices_char[i] = char
    
n_char = len(chars_list)
max_length_x = 128

# 文章をone-hot表現に変換する関数
def sentence_to_vector(sentence):
    vector = np.zeros((1, max_length_x, n_char), dtype=np.bool)
    for j, char in enumerate(sentence):
        vector[0][j][char_indices[char]] = 1
    return vector
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-891c0e32d576> in <module>()
#       3 # インデックスと文字で辞書を作成
#       4 char_indices = {}
# ----> 5 for i, char in enumerate(chars_list):
#       6     char_indices[char] = i
#       7 indices_char = {}
#
# NameError: name 'chars_list' is not defined

# %%
from keras.models import load_model

encoder_model = load_model('encoder_model.h5')
decoder_model = load_model('decoder_model.h5')

def respond(input_data, beta=6):
    state_value = encoder_model.predict(input_data)
    y_decoder = np.zeros((1, 1, n_char))  # decoderの出力を格納する配列
    y_decoder[0][0][char_indices['\t']] = 1  # decoderの最初の入力はタブ。one-hot表現にする。

    respond_sentence = ""  # 返答の文字列
    while True:
        y, h = decoder_model.predict([y_decoder, state_value])
        p_power = y[0][0] ** beta  # 確率分布の調整
        next_index = np.random.choice(len(p_power), p=p_power/np.sum(p_power)) 
        next_char = indices_char[next_index]  # 次の文字
        
        if (next_char == "\n" or len(respond_sentence) >= max_length_x):
            break  # 次の文字が改行のとき、もしくは最大文字数を超えたときは終了
            
        respond_sentence += next_char
        y_decoder = np.zeros((1, 1, n_char))  # 次の時刻の入力
        y_decoder[0][0][next_index] = 1

        state_value = h  # 次の時刻の状態

    return respond_sentence
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-bd99ee7609e3> in <module>()
#       1 from keras.models import load_model
#       2
# ----> 3 encoder_model = load_model('encoder_model.h5')
#       4 decoder_model = load_model('decoder_model.h5')
#       5
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204         filepath = path_to_string(filepath)
#     205         if isinstance(filepath, str):
# --> 206           return saved_model_load.load(filepath, compile, options)
#     207
#     208   raise IOError(
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/saved_model/load.py in load(path, compile, options)
#     107   # Look for metadata file or parse the SavedModel
#     108   metadata = saved_metadata_pb2.SavedMetadata()
# --> 109   meta_graph_def = loader_impl.parse_saved_model(path).meta_graphs[0]
#     110   object_graph_def = meta_graph_def.object_graph_def
#     111   path_to_metadata_pb = os.path.join(path, constants.SAVED_METADATA_PATH)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/loader_impl.py in parse_saved_model(export_dir)
#     114         "SavedModel file does not exist at: %s%s{%s|%s}" %
#     115         (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
# --> 116          constants.SAVED_MODEL_FILENAME_PB))
#     117
#     118
#
# OSError: SavedModel file does not exist at: encoder_model.h5/{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# # 8. 対話の検証

# %%
sentences = ["けんじさん、こんにちは。",
             "カムパネラってしってますか？",
             "ああ、おなかすいた。",
             "きょうはいいてんきですね。",
             "すきなたべものは、なんですか。",
             "きょうは、さんぽにいきました。",
             "パソコンかスマホは、つかったことありますか？"]

for sentence in sentences:
    vector = sentence_to_vector(sentence)
    print("Input:", sentence)
    print("Response", respond(vector))
    print()
# Out:
# Input: けんじさん、こんにちは。
# Response せいねんはいいました。
#
# Input: カムパネラってしってますか？
# Response ジョバンニはまるであいさつして、そこでむねがいっぱいになっていました。
#
# Input: ああ、おなかすいた。
# Response みると、そのときは、あのかわりました。
#
# Input: きょうはいいてんきですね。
# Response それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それか
#
# Input: すきなたべものは、なんですか。
# Response といいました。
#
# Input: きょうは、さんぽにいきました。
# Response それから、そのとき、あかいはかせは、まるでいちめんにおおきなかおをみているのでした。
#
# Input: パソコンかスマホは、つかったことありますか？
# Response そうだ。

# %% [markdown]
# # 9. モデル同士の会話

# %%
response_a = "こんにちは。"
response_b = ""
for i in range(100):
    print("賢治A:", response_a)
    print()  
    vector_a = sentence_to_vector(response_a)
    
    response_b = respond(vector_a)
    print("賢治B:", response_b)
    print()
    vector_b = sentence_to_vector(response_b)
    
    response_a = respond(vector_b)
# Out:
# 賢治A: こんにちは。
#
# 賢治B: はいはいいね。
#
# 賢治A: はやくはなんだか。
#
# 賢治B: はやしのなかではない。
#
# 賢治A: だいへんきょうしつのなかではないんだ。
#
# 賢治B: そのときぼくはもうあのきりのようなものがあるんだ。
#
# 賢治A: そしてまたさぶろうはすこしおおきなこえでした。
#
# 賢治B: それから、そのとき、あかいはかせは、あかいはかせは、そのとき、きつねがいいました。
#
# 賢治A: そしてしばらくあおくひきはじめました。
#
# 賢治B: そしてそのにんは、そのとき、それから、そのとき、あなたのはらのうちにはながれていました。
#
# 賢治A: そしてそのこがありました。
#
# 賢治B: そのにんは、そのとき、ちょうどあのときは、あのかりのひとつのおおきなおおきなひとりのしたにはながら、そのとき、そのとき、ちょうどそのとき、あなたのはらのはなし、そのとき、それから、そのとき、きっとまっくろなのはらのおとこのこがすこしかおをあかくしながら、そ
#
# 賢治A: といいました。
#
# 賢治B: そしてそのときは、あかいはかせは、あかいひをついていきました。
#
# 賢治A: そしてそのときは、あかいはこのときあるいて、あかいはかせは、いちめんにさわって、そのおとこは、そのときあたまをかけて、それからそのままのところへいってしまいました。
#
# 賢治B: そしてそのときは、あかいはかせは、そのあおいかみのように、おおきなこえでした。
#
# 賢治A: ところがそのときは、あかいはかせは、そのときは、あかいはかせのまえにおおきなこえでした。
#
# 賢治B: そしてそのまんなかにはいってきたのです。
#
# 賢治A: かぜのまたさぶろうはまたさぶろうはまたおとうさんのところへいってしまいました。
#
# 賢治B: みんなは、そのときは、あおいひかりをして、それから、そのままのそとをみていましたが、そのとき、おかあさんは、あのかわりました。
#
# 賢治A: それはだいじょうぶです。
#
# 賢治B: けれども、いつかではいってきて、そのとき、きっとまたいっしょうけんいのちになっているんだ。
#
# 賢治A: それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それか
#
# 賢治B: それから、そのかわりになっているのでした。
#
# 賢治A: それから、そのとき、あかいはあのあかりを、あかいはかせのまえにおおきなかたちをして、おおきなはいってきて、そのとき、きしゃは、あおいひかりをつかまえていました。
#
# 賢治B: そしてそのままそのにんのおとうさんが、まっすぐにたっていました。
#
# 賢治A: そのとき、そのとき、きれいなかたちになって、そのとき、あかいはあのあかりが、まるでふたりのきのうたです。
#
# 賢治B: そして、そのときは、あのかりのひかりをして、そのとき、あかいはかせのように、そのしろいはなをあけて、そのとき、あかいはかせは、あのとりとりは、なにかおおきなおおきなかんがえていました。
#
# 賢治A: そしてそのにんは、そのとき、ちょうどそのとき、あかいはかせは、あかいはあのあかりをあげて、そのとききしゃのようになって、そのときあたまをまっあかになって、それから、そのとき、きのうのはなしから、おおきなこえでした。
#
# 賢治B: そしてそのときは、とうとうきょうしつのなかで、あのまえにあたまをあけて、いちめんにいいました。
#
# 賢治A: そしてそのにんは、まるであかいのでした。
#
# 賢治B: かぜのまたさぶろうはまたさぶろうはまたさぶろうはまたいいました。
#
# 賢治A: みんなはまたさぶろうはまたいいました。
#
# 賢治B: ゴーシュはすっかりきげんをなって、まっすぐにたっていました。
#
# 賢治A: するとかっこうはかっこうはまたいいました。
#
# 賢治B: ゴーシュはセロをとりあげていきました。
#
# 賢治A: するとかっこうはまたいっしょに、いっしょにいいました。
#
# 賢治B: ゴーシュはセロをとりました。
#
# 賢治A: するとかっこうはまたいいました。
#
# 賢治B: ゴーシュはセロをとりました。
#
# 賢治A: するとかっこうはまっあかになっていました。
#
# 賢治B: ゴーシュはすこしおおきなかえをみていました。
#
# 賢治A: するとかっこうはまたいっしょに、いっしょにいいました。
#
# 賢治B: ゴーシュはセロをとりました。
#
# 賢治A: するとかっこうはまるであおいひかりをして、そのときとうとうこんどはまたさぶろうはまたいいました。
#
# 賢治B: ゴーシュはセロをとりあげて、それからまたさぶろうはまたいいました。
#
# 賢治A: するとかっこうはまたいいました。
#
# 賢治B: ゴーシュはセロをとりました。
#
# 賢治A: するとかっこうはまたいっぽんのかおをみていましたが、そのときは、あかいはこをかけて、いっしょうけんいのち、あかいひかりをして、そのかわのみずのなかにはいってきて、そのときは、あなたのはらのうえをみていました。
#
# 賢治B: ゴーシュはセロをとりました。
#
# 賢治A: するとかっこうはまたおっかさんが、そのままのそとをみていました。
#
# 賢治B: ゴーシュはセロをとりました。
#
# 賢治A: するとかっこうはまたいっぽんのかわのみずのなかにはしっていきました。
#
# 賢治B: ゴーシュはすこしおおきなかおをみていましたら、そのときは、あおいひかりをつかまえました。
#
# 賢治A: それからあのまえのほうでもうしました。
#
# 賢治B: それから、そのときは、あかいはかせは、そのときは、あかいはあのあかりをあるいていきました。
#
# 賢治A: そしてそのおとこは、ブドリは、そのときあたまをかけて、まっすぐにたっていました。
#
# 賢治B: そのとき、あのかわのみずは、ちいさなこどものじょうに、あおいひがしのほうへはいっているのでした。
#
# 賢治A: そしてそのときは、あかいはいってきて、そのかわのみずのなかにはいってきました。
#
# 賢治B: そしてそのときは、あかいのはらのにんのために、そのとき、きのうたには、とうとうきょうしつのなかで、いちばんのかたちになって、まるでかおをあかくしながら、そのとき、それから、そのとき、それから、そのときは、あかいはあのあかりのようにみえるのでした。
#
# 賢治A: そしてそのときは、あかいはあのあかりを、あるいていました。
#
# 賢治B: そのとき、あすこは、そのとき、あかいのはらのおとこは、なにかのおとこは、きっとみんなはなにかかんがえていましたが、そのとき、おかあさんも、いっしょにひとりのことをいってきました。
#
# 賢治A: そしてそのとき、きつねがいいました。
#
# 賢治B: ぼくはもうそのおとこは、なにかのこっちをみていました。
#
# 賢治A: そしてそのにんは、そのときあたまをかけて、そのときあたまをあけて、それから、そのとき、あかいはかせは、そのときあたまをまげて、あかいはいってきました。
#
# 賢治B: そしてそのときは、あかいはいってきて、おおきなきがして、そのときあたまをまっあかになって、そのときあたまをかけて、まっすぐにたっていました。
#
# 賢治A: そしてそのときは、あのときは、あかいは、あかいはあのあかりをあるいていました。
#
# 賢治B: そしてそのしろいはながあるいて、そこでいっしょに、なにかのかんがえていましたが、そのとき、きつねがいいました。
#
# 賢治A: そしてそのときは、あのあかりをして、はやしのなかにはいっていました。
#
# 賢治B: そしてそのこがありました。
#
# 賢治A: そのとき、そのとき、あかいはいちめんのうちには、いちめんのさんかくしるべのかたちになって、そのとき、ちょうどそのとき、あかいはかせは、あっちへいって、それからはあしをたてていいました。
#
# 賢治B: そしてそのときは、あかいはかせは、ちょっとみていました。
#
# 賢治A: そしてそのにんは、なにかのかたちになって、そのとき、そのとき、きのうのあおいひかりをして、いちめんのきのしたにおちていましたが、そのとき、それから、おおきなこえでした。
#
# 賢治B: そしてそのこがありました。
#
# 賢治A: そのまえにはなにかおもしろいながら、そのとき、あかいはたっていました。
#
# 賢治B: そしてそのまえにはいっているのでした。
#
# 賢治A: ジョバンニは、なにかのおとこは、なにかのおとこのこがいいました。
#
# 賢治B: そのとき、そのとき、そのとき、ちょうどそのとき、あるいているのです。
#
# 賢治A: ホモイはそれをみていました。
#
# 賢治B: そして、そのときは、あかいはかせが、まるでいちめんにいって、それから、そのとき、そのとき、それから、そのとききしゃのおとがして、そのとき、ちょうどそのとき、きつねのうえを、かおをあかくしながら、そのとき、きしゃは、ブドリのおとうさんが、まっあかになって、そ
#
# 賢治A: そしてそのときは、あのまりのあかりを、あかいはあのまっくろなのはらのかたちになって、そのとき、それから、そのとき、きっとまっすぐにたっていました。
#
# 賢治B: そしてそのときは、あかいはかせは、そのにんのおとうさんがききました。
#
# 賢治A: そのとき、そのときは、あのとりのこのこは、あかいはいって、まるでかおをあかくして、そのとききしゃのきょうしつのなかにはいってきました。
#
# 賢治B: そしてまたさぶろうはすっかりおとこのこがだいていきました。
#
# 賢治A: そしてそのおとこは、きっとまっくろなのはらにはいってきました。
#
# 賢治B: そのにちは、あかいのはらのはなしのようなかたちをして、それから、そのときは、あかいはあのあかりをひきました。
#
# 賢治A: そしてそのときは、あのかわりました。
#
# 賢治B: そのとき、ちょうどそのとき、きつねがいっしょに、いっしょに、まるでかおをあかくして、いちめんにきました。
#
# 賢治A: そしてそのしろいはいをかけて、それから、そのときあたまをかけて、そのときは、あかいはながれていました。
#
# 賢治B: そしてそのときは、あのとりのはなして、そのときは、あのとりのところへいってしまいました。
#
# 賢治A: そのとき、ちょうどおまえたちは、あかいはぼくはそのあかりを、あかいはいっていました。
#
# 賢治B: そしてそのときは、あかいはあのあかりをあげて、それから、そのとき、おまえたちは、あかいはいっていました。
#
# 賢治A: そしてそのこどもは、そのとき、そのかわのみずのなかにはいって、そのかわのみずのなかにはいってきて、そのとき、そのとき、そのとき、そのおとこは、なにかのまえにおおきなきがして、それから、そのときあたまをかけて、いっしょうけんいのち、あかいひかりをして、そのと
#
# 賢治B: ところがそのねんは、あかいはいってきたのです。
#
# 賢治A: みんなはまたおっかさんが、まっすぐにたっていました。
#
# 賢治B: ゴーシュはおもわずわらいました。
#
# 賢治A: するとかっこうはまるであのまっくろなくもがないていました。
#
# 賢治B: ゴーシュはセロをとりあげてまっていました。
#
# 賢治A: するとかっこうはまたなにかのかんがえていました。
#
# 賢治B: ゴーシュはおもわずわらいました。
#
# 賢治A: するとかっこうはまたいっぽんのかわのみずのなかにはいってきたのです。
#
# 賢治B: ゴーシュはすこしおおきなかおをみていました。
#
# 賢治A: それからあのまっくろなかおをして、それから、そのとき、あかいはいってきて、それから、いっぽんのかおをみているのでした。
#
# 賢治B: そしてきつねは、そのときあたまをまげて、そのときあしをみました。
#
# 賢治A: ブドリは、なにかのかんそくのはらをあけて、そこでおいて、そこでむねがいっぱいになって、まるでかおをみあげて、それから、まるであいていってしまいました。
#
# 賢治B: そしてそのおとこは、なにかのかたちになって、そのときあたまをまっあかになって、いちめんにおおきなひとりのことをいってきて、そのとき、きしゃは、まるでいちめんにきました。
#
# 賢治A: そしてホモイのおとうさんが、かおをあかくして、いちばんのかいてありました。
#
# 賢治B: ホモイは、そのとき、それから、そのとき、あかいはかせは、おおきなこえでした。
#
# 賢治A: そしてかんもなく、またさぶろうはすっかりおかしくてをつきました。
#
# 賢治B: そしてそのにんは、そのとき、そのとき、それから、そのときは、あのまっくろなしろいものをみました。
#
# 賢治A: そしてそのこどもは、まるでいちめんになって、そのとき、ちょうどそのときあたまをかけて、まっすぐにたっていましたが、そのときは、そのとき、きれいなかおをして、そのひとつのおとこは、なにかのまえのほうへむいていきました。
#
# 賢治B: そのとき、あなたははやく、そのとき、そのとき、ちょうどそのとき、きっとみんなはいってきました。
#
# 賢治A: そしてそのまえにはながら、そのとき、おおきなこえでした。
#
# 賢治B: そのとき、ブドリは、そのとき、そのとき、きつねは、そのとき、あかいのはらのおとこが、いっぽんのおとうさんがききました。
#
# 賢治A: そしてそのまえにはしっていました。
#
# 賢治B: そのとき、ちょうどそのとき、きつねが、いちめんのうちにはいって、まるであおいひかりをみました。
#
# 賢治A: そしてそのこどもがたっていました。
#
# 賢治B: そのとき、ちょうどそのとき、それから、そのとき、あかいはかせは、あかいはあのあかりをいちめんになっていました。
#
# 賢治A: そしてそのおとこは、あのかわのみずのなかにはいってきました。
#
# 賢治B: そしてそのまえには、あかいのはらのおとこが、そのときあたまをかけて、そこから、そのあみをあけました。
#
# 賢治A: そしてそのにんは、あおいひがしのほうへいって、それから、そのとき、ちょうどそのとき、ちょうどあかいのはらのおとこが、いっぽんのおとうさんがききました。
#
# 賢治B: そしてそのときは、あかいはかせのまえにきて、あかいはかせは、そのとき、そのかおをみていましたが、そのとき、どうもありがとう。
#
# 賢治A: といいました。
#
# 賢治B: そしてだいへんあしをみますと、そのときは、あかいはかせは、きっとみんなはなにかかんがえていましたが、そのときは、ああ、とうとうこんにちは、あかいはいってきて、それから、そのときあしをふきました。
#
# 賢治A: そのとき、このときは、あのかわりのように、そのとき、そのとき、そのとき、ぼくはまるであいているのでした。
#
# 賢治B: そしてそのまえにはしっていきました。
#
# 賢治A: そのとき、ちょうどおまえたちのほうでは、いつかでは、いっぽんのかたちになって、そのとき、そのとき、ちょうどそのとき、おおきなきがついているのでした。
#
# 賢治B: そしてそのこどもは、すっかりおかしながら、そのときあたまをかけて、そのままそのにんのおとうさんが、まっあかになって、そのかわりはないから、おおきなこえでした。
#
# 賢治A: そしてそのおとこは、そのときあしをあげて、いきなりそのときあしをみました。
#
# 賢治B: そしてそのおとこは、なにかのかおをあかくして、そのままのそとをみていましたが、そのとき、あかいはいってきました。
#
# 賢治A: そしてそのおとこは、きっとあしをみました。
#
# 賢治B: そのにんは、とうとうこんどはまたいっしょに、なにかのかんがえているのでした。
#
# 賢治A: ジョバンニはまるであかいのようにかえっていましたが、そのときは、ちょうどそのときあるいて、あかいはかせは、そのときふうしゃのなかにはしっていきました。
#
# 賢治B: そのとき、きっとなんだか、そのとき、いちばんはいってきたのです。
#
# 賢治A: そしてそのこどもは、いつかのかんがえていました。
#
# 賢治B: そしてそのときは、あかいはかせは、あかいのはらには、あかいはいっていました。
#
# 賢治A: そしてそのときは、あかいはかせは、そのときは、あかいはかせは、まるであおいひかりをして、そのときあたまをまげていいました。
#
# 賢治B: そしてそのとき、おかあさんが、まるであおいひかりをみました。
#
# 賢治A: そのとき、それは、そのとき、きつねがいっしょに、しろくまっくろなしろいかわのきのうたです。
#
# 賢治B: そしてそのこがありました。
#
# 賢治A: そのとき、あのかわのきしゃは、いっしょうけんいのちになって、いっしょに、このにんたちは、かおをあかくしながら、そのときあるいていってしまいました。
#
# 賢治B: そしてそのおとこは、はやしのなかにとびらをあけました。
#
# 賢治A: そしてそのおとこは、きっとみんなはいってきました。
#
# 賢治B: そしてそのおとこは、なにかのかんがえていました。
#
# 賢治A: そしてそのとき、そのとき、そのとき、それから、そのときあたまをあかくして、そのとき、それから、そのとき、きつねがいいました。
#
# 賢治B: ところがそのこどもは、あのかおをあかくしながら、そのときはしっていました。
#
# 賢治A: そしてそのときあしをたてて、そのとき、そのとき、きつねがいいました。
#
# 賢治B: そのとき、ぼくはもうあのきりのようになっていました。
#
# 賢治A: そしてそのまえにはしっていました。
#
# 賢治B: そのにんは、あかいはいってきたのです。
#
# 賢治A: ジョバンニは、そのとき、それから、そのときあたまをかけて、まっすぐにたっていました。
#
# 賢治B: そのとき、そのとき、みんなは、そのときあたまをまっあかになって、そのおとこのこがありました。
#
# 賢治A: そしてそのこどもは、まるでいちめんにおおきなこえでした。
#
# 賢治B: そしてそのこがありました。
#
# 賢治A: そしてそのときは、あかいはかせは、いちめんのさっきのきのしたにはながら、まるでいちめんにおおきなかおをみていました。
#
# 賢治B: そしてそのときは、あかいはあのあかりのようなしろいはながさいていました。
#
# 賢治A: そのとき、そのとき、ちょうどおまえたちは、あのとりのはなしのはながら、そのかわのみずのなかにはいってきたのです。
#
# 賢治B: ホモイは、きつねがいいました。
#
# 賢治A: むぐらがつちのなかでは、いつかひかりです。
#
# 賢治B: ホモイはおもわずわらいました。
#
# 賢治A: むぐらのおおきなはいってきて、そのときは、まるでいちめんにおおきなかんがえていました。
#
# 賢治B: それから、そのとき、おまえたちは、あのかりのようなかたちをして、そのとききしゃのようなものがあるんだ。
#
# 賢治A: それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それから？それか
#
# 賢治B: それから、そのとき、きつねがいいました。
#
# 賢治A: おまえたちは、あのときは、ちょっとみているのです。
#
# 賢治B: それはいいました。
#
# 賢治A: それから、そのとき、あかいはかせはまるでいちめんにおおきなおおきなこえではいってきたのです。
#
# 賢治B: ところがそのこういちはきょうもあかりをして、そのかわりみずのなかにはしっていきました。
#
# 賢治A: そしてそのときあしをたてて、そのときあたまをあけて、そのときあたまをみていました。
#
# 賢治B: そしてそのときは、あかいはかせが、まるでいちめんにきたのです。
#
# 賢治A: そのとき、ちょうどそのとき、ブドリは、そのときあるいて、ブドリのおとうさんが、いっぽんのかおをみていましたが、そのとき、あかいはかせは、みんなはなにかかきました。
# 賢治B: そしてそのおとこは、もうあのきりのようになって、そのときは、あかいはあのきりのなかにはいってみました。
#
# 賢治A: そしてそのとき、あかいはかせは、そのとき、おおきなこえでした。
#
# 賢治B: そのとき、そのとき、そのときは、あるいて、そのとき、ちょうどそのとき、ちょうどおまえたちのほうでは、あのとりのこのなかにはいっているのでした。
#
# 賢治A: そしてそのまえにちょうどそのとき、それから、そのとき、あかいのはらには、あのとりのきのしたにはながら、そのとき、あかいはかせは、そのばんのあかりをみていました。
#
# 賢治B: そしてそのときは、あかいはかせは、そのとき、ちょうどそのときは、あかいはかせのまえにおおきなきがするのでした。
#
# 賢治A: そしてそのとき、そのとき、あかいはかせは、そのばんのさんかくしるべのあかりを、あかいはあのあかりをつかまえました。
#
# 賢治B: そしてそのにんは、ちょうどそのとき、ブドリは、そのとき、きれいなかおをして、そのときあしをたてて、そのときあたまをひとつとりました。
#
# 賢治A: そしてそのおとこは、きっとみんなはなにかしわのきがいっぱいになりました。
#
# 賢治B: そのとき、ちょうどあのとりのところには、あかいはあのあかりのようなかたちをして、そのとき、きつねのあかりが、まるでいちめんにきたのです。
#
# 賢治A: そしてそのこはあしをあけて、いっしょうけんいのち、あなたのはらにはいっていました。
#
# 賢治B: そしてそのときは、あかいはかせは、そのかわのみずのなかにはいってきました。
#
# 賢治A: そしてそのにんは、あかいのはらのうちにはいっていました。
#
# 賢治B: そのとき、あかいはこんなにんに、そのとき、あかいのことは、あかいのはらのはなしのようになって、そのとき、そこでしたのです。
#
# 賢治A: そしてそのにんは、そのとききしゃのきりのようになって、そのときは、ああ、あかいはいっていました。
#
# 賢治B: そしてそのおとこは、なにかのかんそくのはらをみていましたが、そのとき、それから、どうもありませんでした。
#
# 賢治A: そしてそのおとこは、きっとまっていました。
#
# 賢治B: そしてそのこは、おおきなこえでした。
#
# 賢治A: そのとき、あのかわりは、おおきなきがするのでした。
#
# 賢治B: そしてそのこがいいました。
#
# 賢治A: そのとき、きつねがいいました。
#
# 賢治B: そしてそのこがありました。
#
# 賢治A: そのとき、ちょうどおまえたちのなかで、あのかりのはらは、あのかりのようになって、そのとき、きのうのはなにかんがえているのです。
#
# 賢治B: ホモイはまたいっしょに、まるであしをあげて、そのときにしたのです。
#
# 賢治A: それから、そのとき、あかいはかせは、そのかわりになって、そのとき、ぼくはどうしてもいっしょにいいました。
#
# 賢治B: それから、そのとき、きつねがいいました。
#
# 賢治A: おまえたちは、あのときは、あかいはいっているのです。
#
# 賢治B: それはだいじょうぶだ。
#
# 賢治A: ぼくはもうみんなはないんだ。
#
# 賢治B: おかしいや。
